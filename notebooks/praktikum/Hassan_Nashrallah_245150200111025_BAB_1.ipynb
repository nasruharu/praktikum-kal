# %% [markdown]
# # **Praktikum Kecerdasan Artifisial Lanjutan**
#
#
# ---
# ## Bab 1. Environment Python

# %% [markdown]
# Tuliskan Nama, NIM, dan kelas Anda:
#
# Nama   : Hassan Nashrallah
#
# NIM   : 245150200111025
#
# Kelas : F

# %% [markdown]
# ## Tugas Modul 1

# %% [markdown]
# ### Pertanyaan 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("HARGA TIKET TEMPAT WISATA")
umur = int(input("Masukkan umur pengunjung: "))
hari = input("Masukkan hari pembelian tiket: ")

harga = 50000

if umur < 12 or umur > 60:
  harga -= harga*0.5

if hari == "Sabtu" or hari == "Minggu":
    harga += 10000

if umur >= 12 and umur <= 60:
    if hari != "Sabtu" and hari != "Minggu":
        harga -= 5000

print("Harga akhir tiket: Rp", int(harga))
# Out:
# HARGA TIKET TEMPAT WISATA
# Harga akhir tiket: Rp 60000

# %% [markdown]
# ####Penjelasan

# %% [markdown]
# Pertama-tama, program akan meminta pengguna memasukkan umur dan hari pembelian tiket. Kemudian, variabel harga akan dideklarasikan dengan nilai 50000.
#
# Untuk menentukan harga tiket, dibuat beberapa aturan. Jika umur pengunjung kurang dari 12 tahun atau lebih dari 60 tahun, maka harga tiket akan dikali 0.5, yang sama dengan diskon 50%. Jika tiket dibeli pada hari Sabtu atau Minggu, harga tiket akan ditambahkan 10000. Namun, jika pengunjung berumur 12-60 tahun dan membeli tiket pada hari selain Sabtu dan Minggu, harga tiket akan dikurangi 5000. Hasil akhir perhitungan tiket akan dicetak oleh program

# %% [markdown]
# ### Pertanyaan 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = 4
for i in range(n):
  for j in range(i+1):
    print("*", end=" ")
  print()
# Out:
# *
# * *
# * * *
# * * * *

# %% [markdown]
# ####Penjelasan

# %% [markdown]
# Variabel n menentukan jumlah baris yang akan ditampilkan. Perulangan pertama (for i in range(n)) digunakan untuk mengatur jumlah baris, sedangkan perulangan kedua (for j in range(i+1)) digunakan untuk mengatur jumlah bintang pada setiap baris. Pola untuk menampilkan bintang tersebut adalah jumlah bintang pada baris ke-i sama dengan i + 1, sehingga setiap baris memiliki satu bintang lebih banyak dari baris sebelumnya.

# %% [markdown]
# ### Pertanyaan 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = 4

for i in range(n):
  for j in range((n-1)-i):
    print(" ", end=" ")
  for k in range(i+1):
    print("*", end=" ")
  print()
# Out:
#       *
#     * *
#   * * *
# * * * *

# %% [markdown]
# ####Penjelasan

# %% [markdown]
# Pada program tersebut, spasi dicetak menggunakan perulangan `for j in range((n-1)-i):`. Yang artinya, jumlah spasi pada setiap baris mengikuti rumus (n − 1) − i, dengan n adalah baris dan i adalah indeks baris. Jadi, pola spasi berkurang satu setiap baris, sehingga bintang tampak membentuk segitiga yang rata ke kanan.
#
# Jika n = 4, maka polanya adalah:
# *   Baris 1 (i = 0): (4−1)−0 = 3 spasi
# *   Baris 2 (i = 1): (4−1)−1 = 2 spasi
# *   Baris 3 (i = 2): (4−1)−2 = 1 spasi
# *   Baris 4 (i = 3): (4−1)−3 = 0 spasi

# %% [markdown]
# ### Pertanyaan 4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
kuadrat = lambda x: x*x
print(kuadrat(5))
# Out:
# 25

# %% [markdown]
# ####Penjelasan

# %% [markdown]
# Pada kode ini, `lambda x: x*x` adalah fungsi yang menerima satu parameter x dan mengembalikan hasil kuadrat dari x. Fungsi tersebut disimpan dalam variabel kuadrat. Ketika kuadrat(5) dipanggil, fungsi akan menghitung 5x5 sehingga menghasilkan output 25.

# %% [markdown]
# ### Pertanyaan 5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
jumlah = lambda x, y: x+y
print(jumlah(3, 4))
# Out:
# 7

# %% [markdown]
# ####Penjelasan

# %% [markdown]
# Pada kode ini, `lambda x, y: x+y` adalah fungsi yang menerima dua parameter x dan y, lalu mengembalikan hasil penjumlahan dari x dan y. Hasil tersebut disimpan dalam variabel jumlah. Ketika jumlah(3, 4) dipanggil, fungsi akan menghitung 3+4 sehingga menghasilkan output 7.
